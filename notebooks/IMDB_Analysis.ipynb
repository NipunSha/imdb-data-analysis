# %% [markdown]
# # IMDB Movies Analysis (SQL + Python)
#
# This notebook explores the IMDB Top 1000 movies dataset.
# The goal is to demonstrate data cleaning, SQL-based analysis, and business-focused insights.

# %% [markdown]
# ## Business Questions
#
# - Which movies rank highest by IMDB rating and popularity?
# - Which directors consistently deliver high-rated films?
# - How does revenue vary by decade?
# - Which genres perform best in terms of ratings and gross revenue?
